# %% [markdown]
# ## ETL Process for CDC data

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
# pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Extract Data

# %%
# Store filepath in a variable
input_file = "../static/data/final_df.csv"

# %%
# Read our Data file with the pandas library
raw_df = pd.read_csv(input_file, low_memory=False)

# %%
# Show just the header
raw_df.head()
# Out:
#       Sex  Year of diagnosis  \
# 0  Female               2003
# 1  Female               2018
# 2  Female               2016
# 3    Male               2016
# 4    Male               2016
#
#   Race and origin recode (NHW, NHB, NHAIAN, NHAPI, Hispanic) Survival months  \
# 0                                 Non-Hispanic White                    0014
# 1                                 Non-Hispanic White                    0011
# 2                                 Non-Hispanic White                    0035
# 3                                 Non-Hispanic White                    0035
# 4                                 Non-Hispanic Black                    0024
#
#   Vital status recode (study cutoff used)      Site recode ICD-O-3/WHO 2008  \
# 0                                    Dead                  NHL - Extranodal
# 1                                   Alive                            Breast
# 2                                   Alive                             Ovary
# 3                                   Alive              Melanoma of the Skin
# 4                                   Alive  Other Endocrine including Thymus
#
#   SEER Combined Summary Stage 2000 (2004-2017)  \
# 0                                     Blank(s)
# 1                                     Blank(s)
# 2            Regional by direct extension only
# 3                               Localized only
# 4                               Localized only
#
#   Lymphoma - Ann Arbor Stage (1983-2015) COD to site recode  \
# 0                               Stage II             Breast
# 1                               Blank(s)              Alive
# 2                               Blank(s)              Alive
# 3                               Blank(s)              Alive
# 4                               Blank(s)              Alive
#
#   SEER cause-specific death classification  ...  \
# 0             Alive or dead of other cause  ...
# 1             Alive or dead of other cause  ...
# 2             Alive or dead of other cause  ...
# 3             Alive or dead of other cause  ...
# 4             Alive or dead of other cause  ...
#
#   Number of Cores Positive Recode (2010+)  \
# 0                                Blank(s)
# 1                                Blank(s)
# 2                                Blank(s)
# 3                                Blank(s)
# 4                                Blank(s)
#
#   Number of Cores Examined Recode (2010+)  \
# 0                                Blank(s)
# 1                                Blank(s)
# 2                                Blank(s)
# 3                                Blank(s)
# 4                                Blank(s)
#
#   Number of Examined Pelvic Nodes Recode (2010+)  \
# 0                                       Blank(s)
# 1                                       Blank(s)
# 2                                       Blank(s)
# 3                                       Blank(s)
# 4                                       Blank(s)
#
#   Number of Positive Pelvic Nodes Recode (2010+)  \
# 0                                       Blank(s)
# 1                                       Blank(s)
# 2                                       Blank(s)
# 3                                       Blank(s)
# 4                                       Blank(s)
#
#   Separate Tumor Nodules Ipsilateral Lung Recode (2010+)  \
# 0                                           Blank(s)
# 1                                           Blank(s)
# 2                                           Blank(s)
# 3                                           Blank(s)
# 4                                           Blank(s)
#
#   Tumor Deposits Recode (2010+)  \
# 0                      Blank(s)
# 1                      Blank(s)
# 2                      Blank(s)
# 3                      Blank(s)
# 4                      Blank(s)
#
#   Visceral and Parietal Pleural Invasion Recode (2010+)  \
# 0                                           Blank(s)
# 1                                           Blank(s)
# 2                                           Blank(s)
# 3                                           Blank(s)
# 4                                           Blank(s)
#
#    EOD Regional Nodes (2018+) Tumor Size Summary (2016+)  \
# 0                    Blank(s)                   Blank(s)
# 1                         070                        024
# 2                    Blank(s)                        075
# 3                    Blank(s)                        008
# 4                    Blank(s)                        040
#
#   Regional nodes examined (1988+)
# 0                              99
# 1                               3
# 2                              10
# 3                               0
# 4                               0
#
# [5 rows x 40 columns]

# %%
raw_df.columns
# Out:
# Index(['Sex', 'Year of diagnosis',
#        'Race and origin recode (NHW, NHB, NHAIAN, NHAPI, Hispanic)',
#        'Survival months', 'Vital status recode (study cutoff used)',
#        'Site recode ICD-O-3/WHO 2008',
#        'SEER Combined Summary Stage 2000 (2004-2017)',
#        'Lymphoma - Ann Arbor Stage (1983-2015)', 'COD to site recode',
#        'SEER cause-specific death classification', 'Survival months.1',
#        'Vital status recode (study cutoff used).1',
#        'First malignant primary indicator',
#        'Total number of in situ/malignant tumors for patient',
#        'Total number of benign/borderline tumors for patient',
#        'Age recode with single ages and 85+', 'Race/ethnicity', 'Patient ID',
#        'Rural-Urban Continuum Code',
#        'Age Standard for Survival (15-44,45-54,55-64,65-74,75+)',
#        'RX Summ--Surg Prim Site (1998+)', 'RX Summ--Scope Reg LN Sur (2003+)',
#        'RX Summ--Surg Oth Reg/Dis (2003+)',
#        'Reason no cancer-directed surgery', 'Breslow Thickness Recode (2010+)',
#        'LN Head and Neck Levels I-III Recode (2010+)',
#        'LN Head and Neck Levels IV-V Recode (2010+)',
#        'Lymph Node Size Recode (2010+)', 'Measured Thickness Recode (2010+)',
#        'Measured Basal Diameter Recode (2010+)',
#        'Number of Cores Positive Recode (2010+)',
#        'Number of Cores Examined Recode (2010+)',
#        'Number of Examined Pelvic Nodes Recode (2010+)',
#        'Number of Positive Pelvic Nodes Recode (2010+)',
#        'Separate Tumor Nodules Ipsilateral Lung Recode (2010+)',
#        'Tumor Deposits Recode (2010+)',
#        'Visceral and Parietal Pleural Invasion Recode (2010+)',
#        'EOD Regional Nodes (2018+)', 'Tumor Size Summary (2016+)',
#        'Regional nodes examined (1988+)'],
#       dtype='object')

# %% [markdown]
# ### Transform Data

# %%
# Rename the columns
renamed_df = raw_df.rename(
    columns={"Year of diagnosis": "diagnosis_year",
            "Race and origin recode (NHW, NHB, NHAIAN, NHAPI, Hispanic)": "race_origin",
             "Survival months": "survival_months_str",
             "Vital status recode (study cutoff used)": "status",
             "Site recode ICD-O-3/WHO 2008": "tumour_classification",
             "COD to site recode": "death_cause",
             "SEER cause-specific death classification": "death_classification",
             "Tumor Size Summary (2016+)":"tumor_size_str"
            })
renamed_df.head()
# Out:
#       Sex  diagnosis_year         race_origin survival_months_str status  \
# 0  Female            2003  Non-Hispanic White                0014   Dead
# 1  Female            2018  Non-Hispanic White                0011  Alive
# 2  Female            2016  Non-Hispanic White                0035  Alive
# 3    Male            2016  Non-Hispanic White                0035  Alive
# 4    Male            2016  Non-Hispanic Black                0024  Alive
#
#               tumour_classification  \
# 0                  NHL - Extranodal
# 1                            Breast
# 2                             Ovary
# 3              Melanoma of the Skin
# 4  Other Endocrine including Thymus
#
#   SEER Combined Summary Stage 2000 (2004-2017)  \
# 0                                     Blank(s)
# 1                                     Blank(s)
# 2            Regional by direct extension only
# 3                               Localized only
# 4                               Localized only
#
#   Lymphoma - Ann Arbor Stage (1983-2015) death_cause  \
# 0                               Stage II      Breast
# 1                               Blank(s)       Alive
# 2                               Blank(s)       Alive
# 3                               Blank(s)       Alive
# 4                               Blank(s)       Alive
#
#            death_classification  ... Number of Cores Positive Recode (2010+)  \
# 0  Alive or dead of other cause  ...                                Blank(s)
# 1  Alive or dead of other cause  ...                                Blank(s)
# 2  Alive or dead of other cause  ...                                Blank(s)
# 3  Alive or dead of other cause  ...                                Blank(s)
# 4  Alive or dead of other cause  ...                                Blank(s)
#
#   Number of Cores Examined Recode (2010+)  \
# 0                                Blank(s)
# 1                                Blank(s)
# 2                                Blank(s)
# 3                                Blank(s)
# 4                                Blank(s)
#
#   Number of Examined Pelvic Nodes Recode (2010+)  \
# 0                                       Blank(s)
# 1                                       Blank(s)
# 2                                       Blank(s)
# 3                                       Blank(s)
# 4                                       Blank(s)
#
#   Number of Positive Pelvic Nodes Recode (2010+)  \
# 0                                       Blank(s)
# 1                                       Blank(s)
# 2                                       Blank(s)
# 3                                       Blank(s)
# 4                                       Blank(s)
#
#   Separate Tumor Nodules Ipsilateral Lung Recode (2010+)  \
# 0                                           Blank(s)
# 1                                           Blank(s)
# 2                                           Blank(s)
# 3                                           Blank(s)
# 4                                           Blank(s)
#
#   Tumor Deposits Recode (2010+)  \
# 0                      Blank(s)
# 1                      Blank(s)
# 2                      Blank(s)
# 3                      Blank(s)
# 4                      Blank(s)
#
#   Visceral and Parietal Pleural Invasion Recode (2010+)  \
# 0                                           Blank(s)
# 1                                           Blank(s)
# 2                                           Blank(s)
# 3                                           Blank(s)
# 4                                           Blank(s)
#
#    EOD Regional Nodes (2018+) tumor_size_str Regional nodes examined (1988+)
# 0                    Blank(s)       Blank(s)                              99
# 1                         070            024                               3
# 2                    Blank(s)            075                              10
# 3                    Blank(s)            008                               0
# 4                    Blank(s)            040                               0
#
# [5 rows x 40 columns]

# %%
# Select important features
selected_df = renamed_df[["diagnosis_year", "race_origin", "survival_months_str", "status",
                          "tumour_classification", "death_cause", "death_classification", "tumor_size_str"]]
selected_df.head()
# Out:
#    diagnosis_year         race_origin survival_months_str status  \
# 0            2003  Non-Hispanic White                0014   Dead
# 1            2018  Non-Hispanic White                0011  Alive
# 2            2016  Non-Hispanic White                0035  Alive
# 3            2016  Non-Hispanic White                0035  Alive
# 4            2016  Non-Hispanic Black                0024  Alive
#
#               tumour_classification death_cause          death_classification  \
# 0                  NHL - Extranodal      Breast  Alive or dead of other cause
# 1                            Breast       Alive  Alive or dead of other cause
# 2                             Ovary       Alive  Alive or dead of other cause
# 3              Melanoma of the Skin       Alive  Alive or dead of other cause
# 4  Other Endocrine including Thymus       Alive  Alive or dead of other cause
#
#   tumor_size_str
# 0       Blank(s)
# 1            024
# 2            075
# 3            008
# 4            040

# %%
selected_df.dtypes
# Out:
# diagnosis_year            int64
# race_origin              object
# survival_months_str      object
# status                   object
# tumour_classification    object
# death_cause              object
# death_classification     object
# tumor_size_str           object
# dtype: object

# %%
# Display an overview of the diagnosis_year column
selected_df['diagnosis_year'].value_counts()
# Out:
# 2017    426169
# 2018    424400
# 2016    419876
# 2003     16800
# 2002     16469
# 2001     16089
# 2000     15744
# Name: diagnosis_year, dtype: int64

# %%
# Display an overview of the race_origin column
selected_df['race_origin'].value_counts()
# Out:
# Non-Hispanic White                            917102
# Hispanic (All Races)                          153966
# Non-Hispanic Black                            139808
# Non-Hispanic Asian or Pacific Islander         95882
# Non-Hispanic Unknown Race                      20977
# Non-Hispanic American Indian/Alaska Native      7812
# Name: race_origin, dtype: int64

# %%
# Display an overview of the status column
selected_df['status'].value_counts()
# Out:
# Alive    992819
# Dead     342728
# Name: status, dtype: int64

# %%
# Display an overview of the tumour_classification column
selected_df['tumour_classification'].value_counts()
# Out:
# Breast                              206525
# Prostate                            169436
# Lung and Bronchus                   156449
# NHL - Nodal                          75098
# Melanoma of the Skin                 71834
#                                      ...
# Other Lymphocytic Leukemia              74
# Other Acute Leukemia                    72
# Other Myeloid/Monocytic Leukemia        64
# Pleura                                  64
# Acute Monocytic Leukemia                25
# Name: tumour_classification, Length: 80, dtype: int64

# %%
# Display an overview of the death_cause column
selected_df['death_cause'].value_counts()
# Out:
# Alive                                                 992819
# Lung and Bronchus                                      70223
# Non-Hodgkin Lymphoma                                   28329
# Pancreas                                               25664
# Miscellaneous Malignant Cancer                         22315
#                                                        ...
# Other Male Genital Organs                                 34
# Tuberculosis                                              29
# Acute Monocytic Leukemia                                  21
# Certain Conditions Originating in Perinatal Period         3
# Syphilis                                                   1
# Name: death_cause, Length: 94, dtype: int64

# %%
# Display an overview of the death_classification column
selected_df['death_classification'].value_counts()
# Out:
# Alive or dead of other cause             1066921
# Dead (attributable to this cancer dx)     263913
# Dead (missing/unknown COD)                  4611
# N/A not seq 0-59                             102
# Name: death_classification, dtype: int64

# %%
# Display an overview of the tumor_size column
selected_df['tumor_size_str'].value_counts()
# Out:
# 999         460708
# Blank(s)     65102
# 030          32045
# 020          30308
# 015          29494
#              ...
# 386              1
# 932              1
# 741              1
# 339              1
# 870              1
# Name: tumor_size_str, Length: 486, dtype: int64

# %%
# Replace 'Blank(s)' with '1022'
cleaned_df = selected_df.copy()
# cleaned_df.loc[:,'tumor_size'] = cleaned_df['tumor_size'].replace({'Blank(s)': '1022'})
cleaned_df.loc[:,'tumor_size_int'] = cleaned_df['tumor_size_str'].replace({'Blank(s)': '1022'}).astype(int)
columns=['tumor_size_int']
filter_ = (cleaned_df[columns] <= 988).all(axis=1)
cleaned_df = cleaned_df[filter_]
cleaned_df
# Out:
#          diagnosis_year         race_origin survival_months_str status  \
# 1                  2018  Non-Hispanic White                0011  Alive
# 2                  2016  Non-Hispanic White                0035  Alive
# 3                  2016  Non-Hispanic White                0035  Alive
# 4                  2016  Non-Hispanic Black                0024  Alive
# 5                  2016  Non-Hispanic White                0028  Alive
# ...                 ...                 ...                 ...    ...
# 1335538            2018  Non-Hispanic Black                0000  Alive
# 1335540            2018  Non-Hispanic Black                0000  Alive
# 1335541            2018  Non-Hispanic Black                0001  Alive
# 1335543            2018  Non-Hispanic Black                0000  Alive
# 1335546            2016  Non-Hispanic Black                0034  Alive
#
#                     tumour_classification death_cause  \
# 1                                  Breast       Alive
# 2                                   Ovary       Alive
# 3                    Melanoma of the Skin       Alive
# 4        Other Endocrine including Thymus       Alive
# 5                         Hodgkin - Nodal       Alive
# ...                                   ...         ...
# 1335538                             Cecum       Alive
# 1335540                   Splenic Flexure       Alive
# 1335541                     Sigmoid Colon       Alive
# 1335543                           Thyroid       Alive
# 1335546                            Breast       Alive
#
#                  death_classification tumor_size_str  tumor_size_int
# 1        Alive or dead of other cause            024              24
# 2        Alive or dead of other cause            075              75
# 3        Alive or dead of other cause            008               8
# 4        Alive or dead of other cause            040              40
# 5        Alive or dead of other cause            988             988
# ...                               ...            ...             ...
# 1335538  Alive or dead of other cause            060              60
# 1335540  Alive or dead of other cause            027              27
# 1335541  Alive or dead of other cause            115             115
# 1335543  Alive or dead of other cause            032              32
# 1335546  Alive or dead of other cause            014              14
#
# [806087 rows x 9 columns]

# %%
# cleaned_df = cleaned_df[cleaned_df.tumor_size != '1022']
cleaned_df = cleaned_df.loc[cleaned_df.diagnosis_year == 2018 ]
cleaned_df = cleaned_df.loc[cleaned_df.tumour_classification == 'Breast' ]
# print(f"cleaned_df size: {len(cleaned_df.index)}")
print(f"cleaned_df shape: {cleaned_df.shape}")
# print(f"selected_df size: {len(selected_df.index)}")
print(f"selected_df shape: {selected_df.shape}")
cleaned_df
# Out:
# cleaned_df shape: (65723, 9)
# selected_df shape: (1335547, 8)
#          diagnosis_year           race_origin survival_months_str status  \
# 1                  2018    Non-Hispanic White                0011  Alive
# 19                 2018    Non-Hispanic White                0006  Alive
# 33                 2018  Hispanic (All Races)                0008  Alive
# 34                 2018    Non-Hispanic White                0001  Alive
# 67                 2018    Non-Hispanic White                0006  Alive
# ...                 ...                   ...                 ...    ...
# 1335513            2018    Non-Hispanic White                0009  Alive
# 1335516            2018    Non-Hispanic White                0000  Alive
# 1335522            2018    Non-Hispanic White                0003  Alive
# 1335526            2018    Non-Hispanic White                0003  Alive
# 1335537            2018    Non-Hispanic White                0000  Alive
#
#         tumour_classification death_cause          death_classification  \
# 1                      Breast       Alive  Alive or dead of other cause
# 19                     Breast       Alive  Alive or dead of other cause
# 33                     Breast       Alive  Alive or dead of other cause
# 34                     Breast       Alive  Alive or dead of other cause
# 67                     Breast       Alive  Alive or dead of other cause
# ...                       ...         ...                           ...
# 1335513                Breast       Alive  Alive or dead of other cause
# 1335516                Breast       Alive  Alive or dead of other cause
# 1335522                Breast       Alive  Alive or dead of other cause
# 1335526                Breast       Alive  Alive or dead of other cause
# 1335537                Breast       Alive  Alive or dead of other cause
#
#         tumor_size_str  tumor_size_int
# 1                  024              24
# 19                 008               8
# 33                 020              20
# 34                 021              21
# 67                 005               5
# ...                ...             ...
# 1335513            016              16
# 1335516            006               6
# 1335522            015              15
# 1335526            015              15
# 1335537            018              18
#
# [65723 rows x 9 columns]

# %%
# Display an overview of the survival_months column
cleaned_df['survival_months_str'].value_counts()
# Out:
# 0002       5899
# 0004       5703
# 0001       5377
# 0000       5195
# 0005       5103
# 0006       5097
# 0008       5082
# 0007       5020
# 0010       4916
# 0003       4769
# 0009       4762
# 0011       4536
# 2           404
# 4           373
# 10          364
# 1           363
# 8           358
# 11          356
# 7           351
# 0           347
# 9           346
# 6           343
# 5           333
# 3           318
# Unknown       8
# Name: survival_months_str, dtype: int64

# %%
# Replace 'Unknown' with '9999'
tmp_df = cleaned_df.copy()
tmp_df.loc[:,'survival_months_str'] = tmp_df['survival_months_str'].replace({'Unknown': '9999'})
# Use pd.to_numeric() method to convert the datatype of the Amount column
cleaned_df = tmp_df.copy()
# Release memory assigned to tmp_df 
del tmp_df
# Display an overview of the survival_months column
cleaned_df['survival_months_str'].value_counts() #.sort_values()
# Out:
# 0002    5899
# 0004    5703
# 0001    5377
# 0000    5195
# 0005    5103
# 0006    5097
# 0008    5082
# 0007    5020
# 0010    4916
# 0003    4769
# 0009    4762
# 0011    4536
# 2        404
# 4        373
# 10       364
# 1        363
# 8        358
# 11       356
# 7        351
# 0        347
# 9        346
# 6        343
# 5        333
# 3        318
# 9999       8
# Name: survival_months_str, dtype: int64

# %%
# Fill leading zeros up to four (4) digits
tmp_df = cleaned_df.copy()
tmp_df.loc[:,'survival_months_str'] = tmp_df['survival_months_str'].str.zfill(4)
tmp_df.loc[:,'survival_months_int'] = tmp_df['survival_months_str'].astype(int)
tmp_df = tmp_df.loc[tmp_df.survival_months_int != 9999 ]
cleaned_df = tmp_df.copy()
# Release memory assigned to tmp_df 
del tmp_df
# Display an overview of the survival_months column
cleaned_df['survival_months_str'].value_counts() #.sort_values()
# Out:
# 0002    6303
# 0004    6076
# 0001    5740
# 0000    5542
# 0008    5440
# 0006    5440
# 0005    5436
# 0007    5371
# 0010    5280
# 0009    5108
# 0003    5087
# 0011    4892
# Name: survival_months_str, dtype: int64

# %%
# Grouping the DataFrame by "death_classification"
death_classification_group = cleaned_df.groupby("death_classification")

# Count how many of each component Assignees worked on and create DataFrame
grouped_work_df = pd.DataFrame(death_classification_group["death_cause"].value_counts())
grouped_work_df
# Out:
#                                                                                           death_cause
# death_classification                  death_cause
# Alive or dead of other cause          Alive                                                     64609
#                                       Diseases of Heart                                            88
#                                       Other Cause of Death                                         72
#                                       Cerebrovascular Diseases                                     23
#                                       Lung and Bronchus                                            20
#                                       Diabetes Mellitus                                            18
#                                       Chronic Obstructive Pulmonary Disease and Allie...           17
#                                       Accidents and Adverse Effects                                15
#                                       Septicemia                                                   13
#                                       Pneumonia and Influenza                                      11
#                                       Hypertension without Heart Disease                            8
#                                       Nephritis, Nephrotic Syndrome and Nephrosis                   7
#                                       Alzheimers (ICD-9 and 10 only)                                6
#                                       Colon excluding Rectum                                        6
#                                       Non-Hodgkin Lymphoma                                          5
#                                       Other Infectious and Parasitic Diseases includi...            5
#                                       Symptoms, Signs and Ill-Defined Conditions                    5
#                                       Chronic Liver Disease and Cirrhosis                           4
#                                       Ovary                                                         4
#                                       Suicide and Self-Inflicted Injury                             4
#                                       Acute Myeloid Leukemia                                        3
#                                       Aortic Aneurysm and Dissection                                3
#                                       Homicide and Legal Intervention                               3
#                                       Intrahepatic Bile Duct                                        3
#                                       Myeloma                                                       3
#                                       Pancreas                                                      3
#                                       Atherosclerosis                                               2
#                                       Corpus Uteri                                                  2
#                                       Other Diseases of Arteries, Arterioles, Capilla...            2
#                                       Soft Tissue including Heart                                   2
#                                       Stomach and Duodenal Ulcers                                   2
#                                       Urinary Bladder                                               2
#                                       Brain and Other Nervous System                                1
#                                       Cervix Uteri                                                  1
#                                       Esophagus                                                     1
#                                       Hodgkin Lymphoma                                              1
#                                       Kidney and Renal Pelvis                                       1
#                                       Liver                                                         1
#                                       Miscellaneous Malignant Cancer                                1
#                                       Prostate                                                      1
#                                       Stomach                                                       1
#                                       Thyroid                                                       1
# Dead (attributable to this cancer dx) Breast                                                      671
#                                       Miscellaneous Malignant Cancer                               27
#                                       Lung and Bronchus                                             5
#                                       Brain and Other Nervous System                                3
#                                       Liver                                                         3
#                                       Other Cause of Death                                          3
#                                       In situ, benign or unknown behavior neoplasm                  2
#                                       Myeloma                                                       1
#                                       Other Biliary                                                 1
#                                       Ovary                                                         1
#                                       Stomach                                                       1
# Dead (missing/unknown COD)            State DC not available or state DC available bu...           11
# N/A not seq 0-59                      Alive                                                         6

# %%
# Identify incomplete rows
cleaned_df.count()
# Out:
# diagnosis_year           65715
# race_origin              65715
# survival_months_str      65715
# status                   65715
# tumour_classification    65715
# death_cause              65715
# death_classification     65715
# tumor_size_str           65715
# tumor_size_int           65715
# survival_months_int      65715
# dtype: int64

# %%
cleaned_df = cleaned_df.drop("survival_months_str", axis=1)
cleaned_df = cleaned_df.drop("tumor_size_str", axis=1)
# Rename the columns
cleaned_df = cleaned_df.rename(
    columns={"survival_months_int": "survival_months",
            "tumor_size_int": "tumor_size"
            })
cleaned_df.head()
# Out:
#     diagnosis_year           race_origin status tumour_classification  \
# 1             2018    Non-Hispanic White  Alive                Breast
# 19            2018    Non-Hispanic White  Alive                Breast
# 33            2018  Hispanic (All Races)  Alive                Breast
# 34            2018    Non-Hispanic White  Alive                Breast
# 67            2018    Non-Hispanic White  Alive                Breast
#
#    death_cause          death_classification  tumor_size  survival_months
# 1        Alive  Alive or dead of other cause          24               11
# 19       Alive  Alive or dead of other cause           8                6
# 33       Alive  Alive or dead of other cause          20                8
# 34       Alive  Alive or dead of other cause          21                1
# 67       Alive  Alive or dead of other cause           5                6

# %%
# Identify incomplete rows
cleaned_df.count()
# Out:
# diagnosis_year           65715
# race_origin              65715
# status                   65715
# tumour_classification    65715
# death_cause              65715
# death_classification     65715
# tumor_size               65715
# survival_months          65715
# dtype: int64

# %% [markdown]
# ### Load Data

# %% [markdown]
# Use mongo

# %%
from pymongo import MongoClient
import sys
sys.path.insert(0, '../')
from private import usr, pwd, cluster, db_name # private information, cannot be shared
MONGO_URI = f"mongodb+srv://{usr}:{pwd}@{cluster}/{db_name}"
client = MongoClient(MONGO_URI)

# Define the 'cancer_db' database in Mongo
db = client.cancer_db
collection = db['seer_data']

# %%
new_df = cleaned_df.reset_index(drop=True)
data_dict = new_df.to_dict("records")
new_df
# Out:
#        diagnosis_year           race_origin status tumour_classification  \
# 0                2018    Non-Hispanic White  Alive                Breast
# 1                2018    Non-Hispanic White  Alive                Breast
# 2                2018  Hispanic (All Races)  Alive                Breast
# 3                2018    Non-Hispanic White  Alive                Breast
# 4                2018    Non-Hispanic White  Alive                Breast
# ...               ...                   ...    ...                   ...
# 65710            2018    Non-Hispanic White  Alive                Breast
# 65711            2018    Non-Hispanic White  Alive                Breast
# 65712            2018    Non-Hispanic White  Alive                Breast
# 65713            2018    Non-Hispanic White  Alive                Breast
# 65714            2018    Non-Hispanic White  Alive                Breast
#
#       death_cause          death_classification  tumor_size  survival_months
# 0           Alive  Alive or dead of other cause          24               11
# 1           Alive  Alive or dead of other cause           8                6
# 2           Alive  Alive or dead of other cause          20                8
# 3           Alive  Alive or dead of other cause          21                1
# 4           Alive  Alive or dead of other cause           5                6
# ...           ...                           ...         ...              ...
# 65710       Alive  Alive or dead of other cause          16                9
# 65711       Alive  Alive or dead of other cause           6                0
# 65712       Alive  Alive or dead of other cause          15                3
# 65713       Alive  Alive or dead of other cause          15                3
# 65714       Alive  Alive or dead of other cause          18                0
#
# [65715 rows x 8 columns]

# %%
collection.insert_many(data_dict)
